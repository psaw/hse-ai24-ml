# %% [markdown]
# <a href="https://colab.research.google.com/github/psaw/hse-ai24-ml/blob/main/Cars_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Used car's price prediction
#
# # Шаг 2: разведочный анализ данных

# %% [markdown]
# ## Описание задачи

# %% [markdown]
# Многие знают про маркетплейсы где продаются б/у вещи, на которых есть возможность недорого купить качественную и полезную вещь. Но всегда волнует вопрос - кто и как устанавливает цену, и какие его характеристики больше всего влияют на итоговую стоимость продажи?!
# Вопрос становиться особо актуальным, если речь идет про дорогие товары, например про автомобили!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Импорт библиотек, константы и загрузка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

from urllib.parse import urlencode

# %%
RANDOM_STATE = 42

# %% [markdown]
# Будем работать с данными `train.csv`.
#
# Когда финальная модель будет готова, с помощью нее предскажем цены на машины из файла `test.csv` (там ответов нет).

# %%
TEST = "https://www.dropbox.com/s/asf4b1z1yme5o7u/cars_test.csv?dl=1"
TRAIN = "https://www.dropbox.com/s/qk4b79i7c078sxm/cars_train.csv?dl=1"

# %%
data = pd.read_csv(TRAIN)

# %%
data.shape
# Out:
# (396212, 15)

# %% [markdown]
# Выделим целевую переменную `sellingprice` в отдельную переменную `y`, а `X` - матрица объект-признак.

# %%
X = data.drop('sellingprice', axis=1)
y = data['sellingprice']

# %% [markdown]
# **Описание данных**
#
# **_Признаки_**
# - `year` - год производства
# - `make` - производитель
# - `model` - модель
# - `trim` - модификация
# - `body` - тип кузова
# - `transmission` - тип КПП
# - `vin` - идентификатор (вин)
# - `state` - штат регистрации
# - `condition` - состояние по шкале (1-5)
# - `odometer` - пробег в милях
# - `color` - цвет кузова
# - `interior` - цвет интерьера
# - `seller` - продавец
# - `saledate` - дата продажи
#
# **_Целевой признак_**
# - `sellingprice` - стоимость продажи

# %%
X.head()
# Out:
#    year       make       model     trim       body transmission  \
# 0  2013      Dodge        Dart  Limited      Sedan    automatic
# 1  2014      Honda       Civic       LX      Sedan    automatic
# 2  2012  Chevrolet    Traverse       LT        suv    automatic
# 3  2014     Nissan  Versa Note   1.6 SV  Hatchback    automatic
# 4  2014     Nissan       Versa   1.6 SV      sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  1c3cdfca5dd293552    mo        4.6   13957.0   gray    black
# 1  19xfb2f56ee228781    ca        5.0    2401.0   gray    black
# 2  1gnkrged3cj244704    wi        2.4   70046.0  white    black
# 3  3n1ce2cp9el407766    fl        2.6   23415.0   gray    black
# 4  3n1cn7ap4el813308    il        3.4   17040.0   blue    black
#
#                                 seller  \
# 0                     chrysler capital
# 1     ahfc/honda lease trust/hvt, inc.
# 2             capital one auto finance
# 3         florida auto financial group
# 4  nissan motor acceptance corporation
#
#                                   saledate
# 0  Wed Jan 21 2015 02:30:00 GMT-0800 (PST)
# 1  Thu Feb 26 2015 04:00:00 GMT-0800 (PST)
# 2  Wed Jun 17 2015 03:00:00 GMT-0700 (PDT)
# 3  Tue Feb 17 2015 01:30:00 GMT-0800 (PST)
# 4  Thu Jun 04 2015 03:00:00 GMT-0700 (PDT)

# %% [markdown]
# Посмотрим на типы колонок и число пропущенных значений в них.

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396212 entries, 0 to 396211
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          396212 non-null  int64
#  1   make          388993 non-null  object
#  2   model         388922 non-null  object
#  3   trim          388727 non-null  object
#  4   body          386883 non-null  object
#  5   transmission  350025 non-null  object
#  6   vin           396212 non-null  object
#  7   state         396212 non-null  object
#  8   condition     387759 non-null  float64
#  9   odometer      396151 non-null  float64
#  10  color         395679 non-null  object
#  11  interior      395679 non-null  object
#  12  seller        396212 non-null  object
#  13  saledate      396212 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 42.3+ MB

# %% [markdown]
# Посмотрим на числовые признаки

# %%
X.describe()
# Out:
#                 year      condition       odometer
# count  396212.000000  387759.000000  396151.000000
# mean     2010.041442       3.425687   68336.479029
# std         3.977384       0.949871   53559.280598
# min      1982.000000       1.000000       1.000000
# 25%      2007.000000       2.700000   28259.000000
# 50%      2012.000000       3.600000   52113.000000
# 75%      2013.000000       4.200000   99300.000000
# max      2015.000000       5.000000  999999.000000

# %% [markdown]
# Посмотрим на категориальные признаки

# %%
X.describe(include='object')
# Out:
#           make   model    trim    body transmission                vin  \
# count   388993  388922  388727  386883       350025             396212
# unique      91     949    1899      83            2             396212
# top       Ford  Altima    Base   Sedan    automatic  1c3cdfca5dd293552
# freq     66391   13969   39538  141921       337646                  1
#
#          state   color interior              seller  \
# count   396212  395679   395679              396212
# unique      38      20       17               12530
# top         fl   black    black  nissan-infiniti lt
# freq     59164   78576   173230               14323
#
#                                        saledate
# count                                    396212
# unique                                     3544
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       3783

# %% [markdown]
# Признак `vin` это уникальный идентификатор машины, поэтому удалим его.

# %%
X.drop('vin', axis=1, inplace=True)

# %% [markdown]
# # Разведочный анализ данных

# %% [markdown]
# ## Заполнение пропусков

# %% [markdown]
# Заполним пропуски в числовых столбцах средним значением, а в категориальных - пустой категорией

# %%
for c in X.columns:
    if X[c].dtype == 'object':
          X[c].fillna("", inplace=True)

# %%
for c in X.columns:
    if X[c].dtype != 'object':
          mean = np.mean(X[c])
          X[c].fillna(mean, inplace=True)

# %% [markdown]
# ## Обработка категориальных признаков - 1

# %% [markdown]
# Посмотрим на количество значений в каждой категории

# %%
for c in X.columns:
    if X[c].dtype == 'object':
          print(c, len(X[c].unique()))
# Out:
# make 92
# model 950
# trim 1900
# body 84
# transmission 3
# state 38
# color 21
# interior 18
# seller 12530
# saledate 3544

# %% [markdown]
# В saledate очень много различных значений. Посмотрим почему.

# %%
X[['year','saledate']]
# Out:
#         year                                 saledate
# 0       2013  Wed Jan 21 2015 02:30:00 GMT-0800 (PST)
# 1       2014  Thu Feb 26 2015 04:00:00 GMT-0800 (PST)
# 2       2012  Wed Jun 17 2015 03:00:00 GMT-0700 (PDT)
# 3       2014  Tue Feb 17 2015 01:30:00 GMT-0800 (PST)
# 4       2014  Thu Jun 04 2015 03:00:00 GMT-0700 (PDT)
# ...      ...                                      ...
# 396207  2013  Wed Jun 17 2015 03:00:00 GMT-0700 (PDT)
# 396208  2009  Mon Jun 08 2015 02:00:00 GMT-0700 (PDT)
# 396209  2004  Tue Jan 20 2015 02:30:00 GMT-0800 (PST)
# 396210  2013  Fri Dec 19 2014 11:45:00 GMT-0800 (PST)
# 396211  2012  Wed Feb 04 2015 01:25:00 GMT-0800 (PST)
#
# [396212 rows x 2 columns]

# %% [markdown]
# Обработаем saledate:
# * сделаем признак `car_age` - возраст машины в годах
# * сделаем признак `date` - месяц + год продажи машины (категориальный)
#
# Исходный признак `saledate` удалим

# %%
X['car_age'] = X['saledate'].apply(lambda x: int(x.split(" ")[3])) - X['year']
X['date'] = X['saledate'].apply(lambda x: x.split(" ")[1]+x.split(" ")[3])

X.drop('saledate', axis=1, inplace=True)

# %% [markdown]
# ## Корреляционные матрицы

# %%
import seaborn as sb

X['target'] = y

cols = X.columns[X.dtypes != 'object']

corr = X[cols].corr()
sb.heatmap(corr, cmap="Blues", annot=True)

X.drop('target', axis=1, inplace=True)

# %% [markdown]
# Все числовые признаки важны, запомним это

# %% [markdown]
# Посмотрим на аналог корреляции категориальных признаков

# %%
# !pip install association-metrics
# Out:
# Collecting association-metrics
#   Downloading association-metrics-0.0.1.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: association-metrics
#   Building wheel for association-metrics (setup.py) ... done
#   Created wheel for association-metrics: filename=association_metrics-0.0.1-py3-none-any.whl size=3929 sha256=5dfbba888aec85f3d5c466c4ebba839fb909373602959c1f486846fdbb0e7c91
#   Stored in directory: /root/.cache/pip/wheels/01/47/5f/4360ef6988df6f1b0c1857cab43334269110160bd97b716936
# Successfully built association-metrics
# Installing collected packages: association-metrics
# Successfully installed association-metrics-0.0.1

# %%
import association_metrics as am

XC = X.apply(
        lambda x: x.astype("category") if x.dtype == "object" else x)

cramersv = am.CramersV(XC)

cramersv.fit()
# Out:
#                   make     model      trim      body  transmission     state  \
# make          1.000000  0.942073  0.768825  0.189035      0.161258  0.080016
# model         0.942073  1.000000  0.552843  0.615147      0.310298  0.120689
# trim          0.768825  0.552843  1.000000  0.437450      0.291284  0.131441
# body          0.189035  0.615147  0.437450  1.000000      0.171188  0.054380
# transmission  0.161258  0.310298  0.291284  0.171188      1.000000  0.377115
# state         0.080016  0.120689  0.131441  0.054380      0.377115  1.000000
# color         0.085875  0.145266  0.139243  0.070882      0.063472  0.064536
# interior      0.108237  0.181734  0.210486  0.073898      0.066053  0.062192
# seller        0.405386  0.287182  0.267798  0.251710      0.394181  0.679166
# date          0.059136  0.086036  0.099165  0.298083      0.031898  0.081021
#
#                  color  interior    seller      date
# make          0.085875  0.108237  0.405386  0.059136
# model         0.145266  0.181734  0.287182  0.086036
# trim          0.139243  0.210486  0.267798  0.099165
# body          0.070882  0.073898  0.251710  0.298083
# transmission  0.063472  0.066053  0.394181  0.031898
# state         0.064536  0.062192  0.679166  0.081021
# color         1.000000  0.259053  0.233966  0.018536
# interior      0.259053  1.000000  0.258849  0.061795
# seller        0.233966  0.258849  1.000000  0.286704
# date          0.018536  0.061795  0.286704  1.000000

# %% [markdown]
# Признаки make и model сильно связаны, поэтому уберем make как менее информативный

# %%
X.drop('make', axis=1, inplace=True)

# %% [markdown]
# Как посмотреть влияние категориального признака на целевую переменную? Здесь лучше всего поможет scatterplot

# %%
import seaborn as sns

sns.scatterplot(data=X.iloc[:100], x=X.iloc[:100].index, y=y[:100], hue='date');

# %%
sns.scatterplot(data=X.iloc[:100], x=X.iloc[:100].index, y=y[:100], hue='interior');

# %%
sns.scatterplot(data=X.iloc[:100], x=X.iloc[:100].index, y=y[:100], hue='transmission');

# %% [markdown]
# Посмотрим на распределение целевой переменной

# %%
plt.hist(y, bins=100);

# %% [markdown]
# Пока мы не будем ничего делать с этим распределением, но известно, что с распределениями, отличными от нормального, большинству моделей сложно работать.
#
# Поэтому при улучшении качества базового решения мы преобразуем это распределение.

# %% [markdown]
# ## Поиск аномальных значений

# %%
cat_cols = X.columns[X.dtypes == 'object']
num_cols = X.columns[X.dtypes != 'object']

# %%
for col in num_cols:
    print(col)
    sb.boxplot(X[col])
    plt.show();
# Out:
# year
# condition
# odometer
# car_age

# %%
X[X['odometer'] > 800000][['car_age','odometer']]
# Out:
#         car_age  odometer
# 8651          8  999999.0
# 26775         8  999999.0
# 39643         8  999999.0
# 59125         8  999999.0
# 69969         9  999999.0
# 70028        10  999999.0
# 78649         9  999999.0
# 90539        14  999999.0
# 94884         2  999999.0
# 105833        8  999999.0
# 110191        2  999999.0
# 116616       12  999999.0
# 131952       16  999999.0
# 134612        1  999999.0
# 134857       12  999999.0
# 141001        6  999999.0
# 146938        4  999999.0
# 151038       16  999999.0
# 157027       12  999999.0
# 172362       13  999999.0
# 177204       11  999999.0
# 183102       10  999999.0
# 186281       22  980113.0
# 190359       12  999999.0
# 190713        7  999999.0
# 196941       22  999999.0
# 201525        2  999999.0
# 203849       10  999999.0
# 208501        5  999999.0
# 211364       13  999999.0
# 216791        4  999999.0
# 226333        1  999999.0
# 226829       12  999999.0
# 236744        9  999999.0
# 246775       12  999999.0
# 260672       17  999999.0
# 281362        5  999999.0
# 282290       10  999999.0
# 285173        9  999999.0
# 287839        3  999999.0
# 301621       11  999999.0
# 309564        9  999999.0
# 321203        8  999999.0
# 337569        8  999999.0
# 341542       18  999999.0
# 344155        3  999999.0
# 345128        2  999999.0
# 352157        7  999999.0
# 357647       14  999999.0
# 368070        5  999999.0
# 372689       19  959276.0
# 375085       11  999999.0
# 391998        6  999999.0

# %% [markdown]
# Выкинем машины младше 10 лет, проехавшие 1_000_000 миль - это почти точно выбросы.

# %%
Xnew = X[~((X.car_age < 10) & (X.odometer > 800_000))]
ynew = y[~((X.car_age < 10) & (X.odometer > 800_000))]

Xnew.drop('car_age', axis=1, inplace=True);
# Out:
# <ipython-input-28-065bd109dd0c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xnew.drop('car_age', axis=1, inplace=True);
